# %% [markdown]
# # 0) Imports

# %%
# install the main library YFinance
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.13/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.11.3)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.3.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.16.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %% [markdown]
# # 1) Understanding Data-Driven Decisions data pulls

# %%
end = date.today()
print(f'Year = {end.year}; month= {end.month}; day={end.day}')

start = date(year=end.year-70, month=end.month, day=end.day)
print(f'Period for indexes: {start} to {end} ')
# Out:
# Year = 2026; month= 8; day=23
# Period for indexes: 1956-08-23 to 2026-08-23

# %% [markdown]
# ## 1.1) GDP

# %%
# Real Potential Gross Domestic Product (GDPPOT), Billions of Chained 2012 Dollars, QUARTERLY
# https://fred.stlouisfed.org/series/GDPPOT
gdppot = pdr.DataReader("GDPPOT", "fred", start=start)

# %%
gdppot['gdppot_us_yoy'] = gdppot.GDPPOT/gdppot.GDPPOT.shift(4)-1
gdppot['gdppot_us_qoq'] = gdppot.GDPPOT/gdppot.GDPPOT.shift(1)-1
gdppot.tail(15)
# Out:
#                   GDPPOT  gdppot_us_yoy  gdppot_us_qoq
# DATE
# 2023-01-01  22229.482194       0.025405       0.006551
# 2023-04-01  22377.867950       0.026085       0.006675
# 2023-07-01  22527.570931       0.026560       0.006690
# 2023-10-01  22678.156520       0.026867       0.006685
# 2024-01-01  22828.945411       0.026967       0.006649
# 2024-04-01  22979.033391       0.026864       0.006574
# 2024-07-01  23126.896106       0.026604       0.006435
# 2024-10-01  23271.541687       0.026165       0.006254
# 2025-01-01  23414.656420       0.025657       0.006150
# 2025-04-01  23548.517662       0.024783       0.005717
# 2025-07-01  23680.152477       0.023923       0.005590
# 2025-10-01  23811.223897       0.023191       0.005535
# 2026-01-01  23945.137839       0.022656       0.005624
# 2026-04-01  24070.938648       0.022185       0.005254
# 2026-07-01  24200.444694       0.021972       0.005380

# %%
# Visuals GDPPOT
# https://web.archive.org/web/20250830223438/https://cmdlinetips.com/2019/10/how-to-make-a-plot-with-two-different-y-axis-in-python-with-matplotlib/

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

fig, ax = plt.subplots(figsize=(20, 6))
plt.grid(True)

# Plotting area under US potential GDP curve
ax.fill_between(gdppot.index, gdppot.GDPPOT, color="red", alpha=0.3, label="US Potential GDP")

# Creating a secondary y-axis for GDP growth percentage
ax2 = ax.twinx()
ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax2.plot(gdppot.gdppot_us_yoy, color="blue", marker="o", label="US Potential GDP Growth, % Y/Y")

# Setting labels and title
ax.set_xlabel("Date", fontsize=14)
ax.set_ylabel("US Potential GDP, $b", color="red", fontsize=14)
ax2.set_ylabel("US Potential GDP Growth, % Y/Y", color="blue", fontsize=14)

# Adding legend
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %% [markdown]
# ## 1.2) Inflation - CPI Core

# %%
# # "Core CPI index", MONTHLY
# https://fred.stlouisfed.org/series/CPILFESL
# The "Consumer Price Index for All Urban Consumers: All Items Less Food & Energy"
# is an aggregate of prices paid by urban consumers for a typical basket of goods, excluding food and energy.
# This measurement, known as "Core CPI," is widely used by economists because food and energy have very volatile prices.
cpilfesl = pdr.DataReader("CPILFESL", "fred", start=start)

# %%
cpilfesl.head()
# Out:
#             CPILFESL
# DATE
# 1957-01-01      28.5
# 1957-02-01      28.6
# 1957-03-01      28.7
# 1957-04-01      28.8
# 1957-05-01      28.8

# %%
cpilfesl['cpi_core_yoy'] = cpilfesl.CPILFESL/cpilfesl.CPILFESL.shift(12)-1
cpilfesl['cpi_core_mom'] = cpilfesl.CPILFESL/cpilfesl.CPILFESL.shift(1)-1

cpilfesl.tail(13)
# Out:
#             CPILFESL  cpi_core_yoy  cpi_core_mom
# DATE
# 2025-07-01   328.682      0.030545      0.003125
# 2025-08-01   329.700      0.031118      0.003097
# 2025-09-01   330.418      0.030200      0.002178
# 2025-10-01       NaN           NaN           NaN
# 2025-11-01   331.043      0.025990           NaN
# 2025-12-01   331.814      0.026465      0.002329
# 2026-01-01   332.793      0.025120      0.002950
# 2026-02-01   333.512      0.024725      0.002161
# 2026-03-01   334.165      0.026022      0.001958
# 2026-04-01   335.423      0.027433      0.003765
# 2026-05-01   336.121      0.028229      0.002081
# 2026-06-01   336.065      0.025658     -0.000167
# 2026-07-01   336.789      0.024665      0.002154

# %%
fig, ax = plt.subplots(figsize=(20, 6))
plt.grid(True)

# Plotting area under CPI
ax.fill_between(cpilfesl.index, cpilfesl.CPILFESL, color="red", alpha=0.3, label="Core CPI index (monthly)")

# Creating a secondary y-axis for CPI growth percentage
ax2 = ax.twinx()
ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax2.plot(cpilfesl.cpi_core_yoy, color="blue", marker="o", label="Core CPI index (monthly) Growth, % Y/Y")

# Setting labels and title
ax.set_xlabel("Date", fontsize=14)
ax.set_ylabel("Core CPI index (monthly)", color="red", fontsize=14)
ax2.set_ylabel("Core CPI index Growth, % Y/Y", color="blue", fontsize=14)

# Adding legend
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %% [markdown]
# ## 1.3 Interest rates

# %%
# Fed rate https://fred.stlouisfed.org/series/FEDFUNDS
fedfunds = pdr.DataReader("FEDFUNDS", "fred", start=start)
fedfunds.tail(10)
# Out:
#             FEDFUNDS
# DATE
# 2025-10-01      4.09
# 2025-11-01      3.88
# 2025-12-01      3.72
# 2026-01-01      3.64
# 2026-02-01      3.64
# 2026-03-01      3.64
# 2026-04-01      3.64
# 2026-05-01      3.63
# 2026-06-01      3.63
# 2026-07-01      3.63

# %%
# Fed Funds
fig, ax = plt.subplots(figsize=(20, 6))
plt.grid(True)

# Plotting area under US potential GDP curve
# ax.fill_between(fedfunds.index, fedfunds.FEDFUNDS, color="red", alpha=0.3, label="Core CPI index (monthly)")

# # Creating a secondary y-axis for GDP growth percentage
# ax2 = ax.twinx()
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax.plot(fedfunds.index, fedfunds.FEDFUNDS/100, marker="o", label="Fed Funds Rate")

# Setting labels and title
ax.set_xlabel("Date", fontsize=14)
ax.set_ylabel("Fed Funds Rate", color="blue", fontsize=14)

# Adding legend
lines, labels = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='upper left')

plt.show()

# %%
# https://fred.stlouisfed.org/series/DGS1
dgs1 = pdr.DataReader("DGS1", "fred", start=start)
dgs1.tail()
# Out:
#             DGS1
# DATE
# 2026-08-14  3.98
# 2026-08-17  4.00
# 2026-08-18  3.99
# 2026-08-19  4.00
# 2026-08-20  3.99

# %% [markdown]
# Other rates for US Treasury: https://fred.stlouisfed.org/categories/115
# * https://fred.stlouisfed.org/series/DGS2
# * https://fred.stlouisfed.org/series/DGS3
# * https://fred.stlouisfed.org/series/DGS5
# * https://fred.stlouisfed.org/series/DGS10
# ...

# %%
# https://fred.stlouisfed.org/series/DGS5
dgs5 = pdr.DataReader("DGS5", "fred", start=start)
dgs5.tail()
# Out:
#             DGS5
# DATE
# 2026-08-14  4.36
# 2026-08-17  4.38
# 2026-08-18  4.37
# 2026-08-19  4.35
# 2026-08-20  4.39

# %% [markdown]
# ## 1.4 SNP500

# %%
import yfinance as yf

# Other indexes: https://stooq.com/t/ ; https://stooq.com/t/?i=510  --main indexes
# USED TO BE ABLE TO GET DATA FROM STOOQ USING PDR - NOW, WE USE YAHOO FINANCE
# https://pandas-datareader.readthedocs.io/en/latest/remote_data.html


# SPX= S&P500
ticker_obj = yf.Ticker("^SPX")
spx_index = ticker_obj.history(start=start, end=end)
spx_index.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-08-17 00:00:00-04:00  7790.680176  7790.680176  7744.879883  7745.060059
# 2026-08-18 00:00:00-04:00  7700.040039  7713.950195  7688.629883  7691.759766
# 2026-08-19 00:00:00-04:00  7716.740234  7743.930176  7700.069824  7707.979980
# 2026-08-20 00:00:00-04:00  7690.490234  7699.959961  7639.009766  7641.160156
# 2026-08-21 00:00:00-04:00  7665.680176  7697.109863  7660.060059  7674.370117
#
#                                Volume  Dividends  Stock Splits
# Date
# 2026-08-17 00:00:00-04:00  4452630000        0.0           0.0
# 2026-08-18 00:00:00-04:00  4602700000        0.0           0.0
# 2026-08-19 00:00:00-04:00  5184100000        0.0           0.0
# 2026-08-20 00:00:00-04:00  4759610000        0.0           0.0
# 2026-08-21 00:00:00-04:00  4497270000        0.0           0.0

# %%
spx_index['spx_yoy'] = (spx_index.Close / spx_index.Close.shift(252)) - 1

# Re-truncate the DataFrame after recalculating 'spx_yoy' to ensure data consistency
spx_truncated = spx_index[spx_index.index>='1990-01-01']

# S&P500 abs. vs. relative growth
fig, ax = plt.subplots(figsize=(20, 6))
plt.grid(True)

# Plotting area under S&P 500 Close price
ax.fill_between(spx_truncated.index, spx_truncated.Close, color="red", alpha=0.3, label="S&P 500 Absolute Value (Close price)")

# Creating a secondary y-axis for S&P 500 year-over-year growth percentage
ax2 = ax.twinx()
ax2.yaxis.set_major_formatter(mtick.PercentFormatter(1.0))
ax2.plot(spx_truncated.spx_yoy,
         color="blue",
        #  marker=".",
         label="Year-over-Year Growth (%)")

# Setting labels and title
ax.set_xlabel("Date", fontsize=14)
ax.set_ylabel("S&P 500 Absolute Value (Close price", color="red", fontsize=14)
ax2.set_ylabel("Year-over-Year Growth (%)", color="blue", fontsize=14)

# Adding legend
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

plt.show()

# %% [markdown]
# # 2) Data Sources for Stocks

# %% [markdown]
# ## 2.1 OHLCV data daily - INDEXES

# %%
# INDEXES from Yahoo Finance
# DAX index (XETRA - XETRA Delayed Price. Currency in EUR)
# WEB: https://finance.yahoo.com/quote/%5EGDAXI
# Option 1: dax_daily = yf.download(tickers = ["^GDAXI"],
#                      period = "max",
#                      interval = "1d")

# Option 2 (preferred):
# Download data with Adj Close for more accurate price reflections
ticker_obj = yf.Ticker("^GDAXI")
dax_daily = ticker_obj.history(start = start)

# %%
dax_daily.tail()
# Out:
#                                    Open          High           Low  \
# Date
# 2026-08-17 00:00:00+02:00  26490.300781  26493.500000  26338.609375
# 2026-08-18 00:00:00+02:00  26280.859375  26292.949219  26119.539062
# 2026-08-19 00:00:00+02:00  26146.119141  26187.820312  26063.369141
# 2026-08-20 00:00:00+02:00  26050.949219  26062.150391  25914.109375
# 2026-08-21 00:00:00+02:00  25998.949219  26166.250000  25969.519531
#
#                                   Close    Volume  Dividends  Stock Splits
# Date
# 2026-08-17 00:00:00+02:00  26338.609375  38194400        0.0           0.0
# 2026-08-18 00:00:00+02:00  26128.359375  47429900        0.0           0.0
# 2026-08-19 00:00:00+02:00  26091.330078  46190700        0.0           0.0
# 2026-08-20 00:00:00+02:00  25983.039062  37334800        0.0           0.0
# 2026-08-21 00:00:00+02:00  26136.560547  43329100        0.0           0.0

# %%
# normally 252 trading days
dax_daily['adj_close_last_year'] = dax_daily['Close'].shift(252)
dax_daily['yoy_growth'] = dax_daily['Close'] / dax_daily['adj_close_last_year'] -1

# %%
dax_daily
# Out:
#                                    Open          High           Low  \
# Date
# 1987-12-30 00:00:00+01:00   1005.190002   1005.190002   1005.190002
# 1988-01-04 00:00:00+01:00    956.489990    956.489990    956.489990
# 1988-01-05 00:00:00+01:00    996.099976    996.099976    996.099976
# 1988-01-06 00:00:00+01:00   1006.010010   1006.010010   1006.010010
# 1988-01-07 00:00:00+01:00   1014.469971   1014.469971   1014.469971
# ...                                 ...           ...           ...
# 2026-08-17 00:00:00+02:00  26490.300781  26493.500000  26338.609375
# 2026-08-18 00:00:00+02:00  26280.859375  26292.949219  26119.539062
# 2026-08-19 00:00:00+02:00  26146.119141  26187.820312  26063.369141
# 2026-08-20 00:00:00+02:00  26050.949219  26062.150391  25914.109375
# 2026-08-21 00:00:00+02:00  25998.949219  26166.250000  25969.519531
#
#                                   Close    Volume  Dividends  Stock Splits  \
# Date
# 1987-12-30 00:00:00+01:00   1005.190002         0        0.0           0.0
# 1988-01-04 00:00:00+01:00    956.489990         0        0.0           0.0
# 1988-01-05 00:00:00+01:00    996.099976         0        0.0           0.0
# 1988-01-06 00:00:00+01:00   1006.010010         0        0.0           0.0
# 1988-01-07 00:00:00+01:00   1014.469971         0        0.0           0.0
# ...                                 ...       ...        ...           ...
# 2026-08-17 00:00:00+02:00  26338.609375  38194400        0.0           0.0
# 2026-08-18 00:00:00+02:00  26128.359375  47429900        0.0           0.0
# 2026-08-19 00:00:00+02:00  26091.330078  46190700        0.0           0.0
# 2026-08-20 00:00:00+02:00  25983.039062  37334800        0.0           0.0
# 2026-08-21 00:00:00+02:00  26136.560547  43329100        0.0           0.0
#
#                            adj_close_last_year  yoy_growth
# Date
# 1987-12-30 00:00:00+01:00                  NaN         NaN
# 1988-01-04 00:00:00+01:00                  NaN         NaN
# 1988-01-05 00:00:00+01:00                  NaN         NaN
# 1988-01-06 00:00:00+01:00                  NaN         NaN
# 1988-01-07 00:00:00+01:00                  NaN         NaN
# ...                                        ...         ...
# 2026-08-17 00:00:00+02:00         24314.769531    0.083235
# 2026-08-18 00:00:00+02:00         24423.070312    0.069823
# 2026-08-19 00:00:00+02:00         24276.970703    0.074736
# 2026-08-20 00:00:00+02:00         24293.339844    0.069554
# 2026-08-21 00:00:00+02:00         24363.089844    0.072793
#
# [9772 rows x 9 columns]

# %%
dax_daily['Close'].plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
# delayed 15 min : https://finance.yahoo.com/quote/%5ESPX/
# S&P 500 INDEX : Chicago Options - Chicago Options Delayed Price. Currency in USD
ticker_obj = yf.Ticker("^SPX")
snp500_daily = ticker_obj.history(start = start, interval = "1d")

# old version:
# snp500_daily = yf.download(tickers = "^SPX",
#                      period = "max",
#                      interval = "1d")

# %%
snp500_daily.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-08-17 00:00:00-04:00  7790.680176  7790.680176  7744.879883  7745.060059
# 2026-08-18 00:00:00-04:00  7700.040039  7713.950195  7688.629883  7691.759766
# 2026-08-19 00:00:00-04:00  7716.740234  7743.930176  7700.069824  7707.979980
# 2026-08-20 00:00:00-04:00  7690.490234  7699.959961  7639.009766  7641.160156
# 2026-08-21 00:00:00-04:00  7665.680176  7697.109863  7660.060059  7674.370117
#
#                                Volume  Dividends  Stock Splits
# Date
# 2026-08-17 00:00:00-04:00  4452630000        0.0           0.0
# 2026-08-18 00:00:00-04:00  4602700000        0.0           0.0
# 2026-08-19 00:00:00-04:00  5184100000        0.0           0.0
# 2026-08-20 00:00:00-04:00  4759610000        0.0           0.0
# 2026-08-21 00:00:00-04:00  4497270000        0.0           0.0

# %%
# https://finance.yahoo.com/quote/%5EGSPC/
# SNP - SNP Real Time Price. Currency in USD
# https://www.investopedia.com/insights/introduction-to-stock-market-indices/

ticker_obj = yf.Ticker("^GSPC")
snp500_daily_non_delayed = ticker_obj.history(start = start, interval = "1d")

# old version:
# snp500_daily_non_delayed = yf.download(tickers = "^GSPC",
#                      period = "max",
#                      interval = "1d")

# %%
snp500_daily_non_delayed.tail()
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2026-08-17 00:00:00-04:00  7790.680176  7790.680176  7744.879883  7745.060059
# 2026-08-18 00:00:00-04:00  7700.040039  7713.950195  7688.629883  7691.759766
# 2026-08-19 00:00:00-04:00  7716.740234  7743.930176  7700.069824  7707.979980
# 2026-08-20 00:00:00-04:00  7690.490234  7699.959961  7639.009766  7641.160156
# 2026-08-21 00:00:00-04:00  7665.680176  7697.109863  7660.060059  7674.370117
#
#                                Volume  Dividends  Stock Splits
# Date
# 2026-08-17 00:00:00-04:00  4452630000        0.0           0.0
# 2026-08-18 00:00:00-04:00  4602700000        0.0           0.0
# 2026-08-19 00:00:00-04:00  5184100000        0.0           0.0
# 2026-08-20 00:00:00-04:00  4759610000        0.0           0.0
# 2026-08-21 00:00:00-04:00  4497270000        0.0           0.0

# %%
# Dow Jones Industrial Average: https://finance.yahoo.com/quote/%5EDJI?.tsrc=fin-srch

ticker_obj = yf.Ticker("^DJI")
dji_daily = ticker_obj.history(start = start, interval = "1d")

# dji_daily = yf.download(tickers = "^DJI",
#                      period = "max",
#                      interval = "1d")

# %% [markdown]
# ## 2.2 OHLCV data daily - ETFs

# %%
# https://finance.yahoo.com/quote/VOO?.tsrc=fin-srch

ticker_obj = yf.Ticker("VOO")
voo_etf = ticker_obj.history(start = start, interval = "1d")

# voo_etf = yf.download(tickers = "VOO",
#                      period = "max",
#                      interval = "1d")

# %%
voo_etf.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-08-17 00:00:00-04:00  713.500000  714.049988  710.099976  710.270020
# 2026-08-18 00:00:00-04:00  706.609985  707.349976  704.960022  705.400024
# 2026-08-19 00:00:00-04:00  708.190002  710.099976  706.099976  706.909973
# 2026-08-20 00:00:00-04:00  704.049988  706.080017  700.469971  701.010010
# 2026-08-21 00:00:00-04:00  704.070007  705.799988  702.440002  703.710022
#
#                              Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2026-08-17 00:00:00-04:00   5745000        0.0           0.0            0.0
# 2026-08-18 00:00:00-04:00   5278600        0.0           0.0            0.0
# 2026-08-19 00:00:00-04:00   7021800        0.0           0.0            0.0
# 2026-08-20 00:00:00-04:00   8458600        0.0           0.0            0.0
# 2026-08-21 00:00:00-04:00  10693400        0.0           0.0            0.0

# %%
# ETFs
# WisdomTree India Earnings Fund (EPI)
# NYSEArca - Nasdaq Real Time Price. Currency in USD
# WEB: https://finance.yahoo.com/quote/EPI/history?p=EPI

ticker_obj = yf.Ticker("EPI")
epi_etf_daily = ticker_obj.history(start = start, interval = "1d")

# epi_etf_daily = yf.download(tickers = "EPI",
#                      period = "max",
#                      interval = "1d")

# %%
epi_etf_daily.head()
print(epi_etf_daily.shape)
# Out:
# (4652, 8)

# %%
# find dividends impact on Close vs. Adj.Close
epi_etf_daily[epi_etf_daily.Dividends>0].tail()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2021-12-27 00:00:00-05:00  33.577707  33.801809  33.577707  33.764458  379100
# 2022-03-25 00:00:00-04:00  33.563275  33.666313  33.432129  33.666313  584400
# 2022-06-24 00:00:00-04:00  29.420327  29.778748  29.370547  29.768791  387900
# 2023-06-26 00:00:00-04:00  34.020314  34.070182  33.960471  33.990395  634600
# 2024-12-26 00:00:00-05:00  45.840000  45.840000  45.700001  45.820000  685600
#
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2021-12-27 00:00:00-05:00      0.192           0.0            0.0
# 2022-03-25 00:00:00-04:00      0.115           0.0            0.0
# 2022-06-24 00:00:00-04:00      1.845           0.0            0.0
# 2023-06-26 00:00:00-04:00      0.060           0.0            0.0
# 2024-12-26 00:00:00-05:00      0.121           0.0            0.0

# %%
epi_etf_daily[(epi_etf_daily.index >='2024-12-23') & (epi_etf_daily.index <='2024-12-28')]
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2024-12-23 00:00:00-05:00  45.609761  45.879052  45.609761  45.869080  630400
# 2024-12-24 00:00:00-05:00  45.719475  45.928922  45.709503  45.899002  277100
# 2024-12-26 00:00:00-05:00  45.840000  45.840000  45.700001  45.820000  685600
# 2024-12-27 00:00:00-05:00  45.570000  45.650002  45.500000  45.639999  774900
#
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2024-12-23 00:00:00-05:00      0.000           0.0            0.0
# 2024-12-24 00:00:00-05:00      0.000           0.0            0.0
# 2024-12-26 00:00:00-05:00      0.121           0.0            0.0
# 2024-12-27 00:00:00-05:00      0.000           0.0            0.0

# %%
# find dividends - diff for Close vs. Adj Close
# Open/Close for 06-25 diff is close to divs = 1.845 (~1.58 for Open and 1.3 for Close)
# HELP: https://help.yahoo.com/kb/SLN28256.html#:~:text=Adjusted%20close%20is%20the%20closing,Security%20Prices%20(CRSP)%20standards.
epi_etf_daily[(epi_etf_daily.index >='2024-12-23') & (epi_etf_daily.index <='2024-12-28')]
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2024-12-23 00:00:00-05:00  45.609761  45.879052  45.609761  45.869080  630400
# 2024-12-24 00:00:00-05:00  45.719475  45.928922  45.709503  45.899002  277100
# 2024-12-26 00:00:00-05:00  45.840000  45.840000  45.700001  45.820000  685600
# 2024-12-27 00:00:00-05:00  45.570000  45.650002  45.500000  45.639999  774900
#
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2024-12-23 00:00:00-05:00      0.000           0.0            0.0
# 2024-12-24 00:00:00-05:00      0.000           0.0            0.0
# 2024-12-26 00:00:00-05:00      0.121           0.0            0.0
# 2024-12-27 00:00:00-05:00      0.000           0.0            0.0

# %%
# Previous option : no Div. dates , same stats
epi_etf_daily2 = yf.download(tickers = "EPI",
                     period = "max",
                     interval = "1d")
# Out:
# /tmp/ipykernel_12852/3463259538.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   epi_etf_daily2 = yf.download(tickers = "EPI",
# [*********************100%***********************]  1 of 1 completed

# %%
epi_etf_daily2[epi_etf_daily2.index>='2024-12-23'].head()
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker            EPI        EPI        EPI        EPI      EPI
# Date
# 2024-12-23  45.869080  45.879052  45.609761  45.609761   630400
# 2024-12-24  45.899002  45.928922  45.709503  45.719475   277100
# 2024-12-26  45.820000  45.840000  45.700001  45.840000   685600
# 2024-12-27  45.639999  45.650002  45.500000  45.570000   774900
# 2024-12-30  45.090000  45.180000  44.980000  45.180000  1442100

# %%
# About yFinance: https://zoo.cs.yale.edu/classes/cs458/lectures/yfinance.html

epi_etf_daily['Close'].plot(title="EPI's etf stock price")
# Out:
# <Axes: title={'center': "EPI's etf stock price"}, xlabel='Date'>

# %%
# get actions, incl. dividends - as a dataFrame
epi = yf.Ticker('EPI')
epi.get_actions()
# Out:
#                            Dividends  Stock Splits  Capital Gains
# Date
# 2008-12-22 00:00:00-05:00      0.091           0.0            0.0
# 2009-03-23 00:00:00-04:00      0.007           0.0            0.0
# 2009-06-22 00:00:00-04:00      0.002           0.0            0.0
# 2009-09-21 00:00:00-04:00      0.045           0.0            0.0
# 2009-12-21 00:00:00-05:00      0.006           0.0            0.0
# 2010-06-28 00:00:00-04:00      0.065           0.0            0.0
# 2010-09-20 00:00:00-04:00      0.065           0.0            0.0
# 2010-12-22 00:00:00-05:00      0.013           0.0            0.0
# 2011-06-22 00:00:00-04:00      0.062           0.0            0.0
# 2011-09-26 00:00:00-04:00      0.098           0.0            0.0
# 2012-03-26 00:00:00-04:00      0.010           0.0            0.0
# 2012-06-25 00:00:00-04:00      0.045           0.0            0.0
# 2012-09-24 00:00:00-04:00      0.083           0.0            0.0
# 2012-12-24 00:00:00-05:00      0.024           0.0            0.0
# 2013-06-24 00:00:00-04:00      0.068           0.0            0.0
# 2013-09-23 00:00:00-04:00      0.063           0.0            0.0
# 2014-03-24 00:00:00-04:00      0.099           0.0            0.0
# 2014-06-23 00:00:00-04:00      0.059           0.0            0.0
# 2014-09-22 00:00:00-04:00      0.068           0.0            0.0
# 2015-03-23 00:00:00-04:00      0.031           0.0            0.0
# 2015-06-22 00:00:00-04:00      0.067           0.0            0.0
# 2015-09-21 00:00:00-04:00      0.116           0.0            0.0
# 2015-12-21 00:00:00-05:00      0.024           0.0            0.0
# 2016-03-21 00:00:00-04:00      0.010           0.0            0.0
# 2016-06-20 00:00:00-04:00      0.125           0.0            0.0
# 2016-09-26 00:00:00-04:00      0.070           0.0            0.0
# 2016-12-23 00:00:00-05:00      0.006           0.0            0.0
# 2017-03-27 00:00:00-04:00      0.075           0.0            0.0
# 2017-06-26 00:00:00-04:00      0.055           0.0            0.0
# 2017-09-26 00:00:00-04:00      0.080           0.0            0.0
# 2017-12-26 00:00:00-05:00      0.026           0.0            0.0
# 2018-03-20 00:00:00-04:00      0.061           0.0            0.0
# 2018-06-25 00:00:00-04:00      0.085           0.0            0.0
# 2018-09-25 00:00:00-04:00      0.111           0.0            0.0
# 2018-12-24 00:00:00-05:00      0.008           0.0            0.0
# 2018-12-28 00:00:00-05:00      0.028           0.0            0.0
# 2019-03-26 00:00:00-04:00      0.120           0.0            0.0
# 2019-09-24 00:00:00-04:00      0.130           0.0            0.0
# 2019-12-23 00:00:00-05:00      0.041           0.0            0.0
# 2020-03-24 00:00:00-04:00      0.017           0.0            0.0
# 2020-06-23 00:00:00-04:00      0.094           0.0            0.0
# 2020-09-22 00:00:00-04:00      0.035           0.0            0.0
# 2020-12-21 00:00:00-05:00      0.081           0.0            0.0
# 2021-03-25 00:00:00-04:00      0.043           0.0            0.0
# 2021-06-24 00:00:00-04:00      0.085           0.0            0.0
# 2021-09-24 00:00:00-04:00      0.110           0.0            0.0
# 2021-12-27 00:00:00-05:00      0.192           0.0            0.0
# 2022-03-25 00:00:00-04:00      0.115           0.0            0.0
# 2022-06-24 00:00:00-04:00      1.845           0.0            0.0
# 2023-06-26 00:00:00-04:00      0.060           0.0            0.0
# 2024-12-26 00:00:00-05:00      0.121           0.0            0.0

# %%
# get dividends as Series
epi.get_dividends()
# Out:
# Date
# 2008-12-22 00:00:00-05:00    0.091
# 2009-03-23 00:00:00-04:00    0.007
# 2009-06-22 00:00:00-04:00    0.002
# 2009-09-21 00:00:00-04:00    0.045
# 2009-12-21 00:00:00-05:00    0.006
# 2010-06-28 00:00:00-04:00    0.065
# 2010-09-20 00:00:00-04:00    0.065
# 2010-12-22 00:00:00-05:00    0.013
# 2011-06-22 00:00:00-04:00    0.062
# 2011-09-26 00:00:00-04:00    0.098
# 2012-03-26 00:00:00-04:00    0.010
# 2012-06-25 00:00:00-04:00    0.045
# 2012-09-24 00:00:00-04:00    0.083
# 2012-12-24 00:00:00-05:00    0.024
# 2013-06-24 00:00:00-04:00    0.068
# 2013-09-23 00:00:00-04:00    0.063
# 2014-03-24 00:00:00-04:00    0.099
# 2014-06-23 00:00:00-04:00    0.059
# 2014-09-22 00:00:00-04:00    0.068
# 2015-03-23 00:00:00-04:00    0.031
# 2015-06-22 00:00:00-04:00    0.067
# 2015-09-21 00:00:00-04:00    0.116
# 2015-12-21 00:00:00-05:00    0.024
# 2016-03-21 00:00:00-04:00    0.010
# 2016-06-20 00:00:00-04:00    0.125
# 2016-09-26 00:00:00-04:00    0.070
# 2016-12-23 00:00:00-05:00    0.006
# 2017-03-27 00:00:00-04:00    0.075
# 2017-06-26 00:00:00-04:00    0.055
# 2017-09-26 00:00:00-04:00    0.080
# 2017-12-26 00:00:00-05:00    0.026
# 2018-03-20 00:00:00-04:00    0.061
# 2018-06-25 00:00:00-04:00    0.085
# 2018-09-25 00:00:00-04:00    0.111
# 2018-12-24 00:00:00-05:00    0.008
# 2018-12-28 00:00:00-05:00    0.028
# 2019-03-26 00:00:00-04:00    0.120
# 2019-09-24 00:00:00-04:00    0.130
# 2019-12-23 00:00:00-05:00    0.041
# 2020-03-24 00:00:00-04:00    0.017
# 2020-06-23 00:00:00-04:00    0.094
# 2020-09-22 00:00:00-04:00    0.035
# 2020-12-21 00:00:00-05:00    0.081
# 2021-03-25 00:00:00-04:00    0.043
# 2021-06-24 00:00:00-04:00    0.085
# 2021-09-24 00:00:00-04:00    0.110
# 2021-12-27 00:00:00-05:00    0.192
# 2022-03-25 00:00:00-04:00    0.115
# 2022-06-24 00:00:00-04:00    1.845
# 2023-06-26 00:00:00-04:00    0.060
# 2024-12-26 00:00:00-05:00    0.121
# Name: Dividends, dtype: float64

# %%
# India's stock example
# https://www.nseindia.com/market-data/live-equity-market
EICHERMOT = yf.download(tickers = "EICHERMOT.NS",
                     period = "max",
                     interval = "1d")
# Out:
# /tmp/ipykernel_12852/1576332518.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   EICHERMOT = yf.download(tickers = "EICHERMOT.NS",
# [*********************100%***********************]  1 of 1 completed

# %%
EICHERMOT
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     EICHERMOT.NS EICHERMOT.NS EICHERMOT.NS EICHERMOT.NS EICHERMOT.NS
# Date
# 1996-01-01     1.119487     1.119487     1.119487     1.119487        22000
# 1996-01-02     1.122596     1.131925     1.119487     1.119487        31000
# 1996-01-03     1.135035     1.135035     1.135035     1.135035        11000
# 1996-01-04     1.135035     1.135035     1.119487     1.119487        16000
# 1996-01-05     1.119487     1.135035     1.100829     1.135035         6000
# ...                 ...          ...          ...          ...          ...
# 2026-08-17  8050.000000  8165.000000  8050.000000  8058.000000       397488
# 2026-08-18  8018.500000  8107.000000  8016.500000  8040.000000       262500
# 2026-08-19  7990.500000  8060.000000  7947.500000  8016.500000       344004
# 2026-08-20  8042.000000  8097.500000  7983.000000  8047.000000       323672
# 2026-08-21  8010.000000  8112.500000  7980.000000  8095.000000       316029
#
# [7691 rows x 5 columns]

# %% [markdown]
# ## 2.3 Paid data - Poligon.io (news endpoint) and Alpha Vantage

# %%
# [Polygon.io] Please read the article (section "Polygon.io News API"): https://pythoninvest.com/long-read/chatgpt-api-for-financial-news-summarization
# Endpoint: https://polygon.io/docs/stocks/get_v2_reference_news

# %%
# [Alpha Vantage] Please read the article (section "Data Sources"): https://pythoninvest.com/long-read/stock-screening-using-paid-data
# Endpoint: https://www.alphavantage.co/documentation/#fundamentals

# %% [markdown]
# ## 2.4 Macroeconomics
#
# * some indicator examples: gold reserves vs. volatility

# %%
# Gold reserves excl. gold for China
# https://fred.stlouisfed.org/series/TRESEGCNM052N

# %%
gold_reserves = pdr.DataReader("TRESEGCNM052N", "fred", start=start)

# %%
gold_reserves.TRESEGCNM052N.plot.line()
# Out:
# <Axes: xlabel='DATE'>

# %%
#  CBOE Gold ETF Volatility Index (GVZCLS)
# https://fred.stlouisfed.org/series/GVZCLS
gold_volatility = pdr.DataReader("GVZCLS", "fred", start=start)

# %%
gold_volatility.GVZCLS.plot.line()
# Out:
# <Axes: xlabel='DATE'>

# %%
#  Crude Oil Prices: West Texas Intermediate (WTI) - Cushing, Oklahoma (DCOILWTICO)
# https://fred.stlouisfed.org/series/DCOILWTICO
oil_wti = pdr.DataReader("DCOILWTICO", "fred", start=start)

# %%
# there is a bug in the data? negative price?
oil_wti.DCOILWTICO.plot.line()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Crude Oil Prices: Brent - Europe (DCOILBRENTEU)
# https://fred.stlouisfed.org/series/DCOILBRENTEU
oil_brent = pdr.DataReader("DCOILBRENTEU", "fred", start=start)

# %%
oil_brent.DCOILBRENTEU.plot.line()
# Out:
# <Axes: xlabel='DATE'>

# %%
# Web Scraping for Macro
# can't call directly via pd.read_html() as it returns 403 (forbidden) --> need to do a bit of work, but still no Selenium
# https://tradingeconomics.com/united-states/indicators
import requests
from bs4 import BeautifulSoup


url = "https://tradingeconomics.com/united-states/indicators"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

response = requests.get(url, headers=headers)

# %%
# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the webpage
    soup = BeautifulSoup(response.content, "html.parser")

    # You need to be able to find this table tag and read all behind it
    # Find the div with class "table-responsive"
    table_div = soup.find("div", class_="table-responsive")

    # Extract the table within the div
    table = table_div.find("table")

    # Use pandas to read the table into a DataFrame
    df = pd.read_html(str(table))[0]  # Assuming there's only one table, otherwise, loop through the list

    # Display the DataFrame
    print(df)
else:
    print("Failed to retrieve data from the webpage.")
# Out:
#                   Unnamed: 0     Last  Previous  Highest    Lowest  \
# 0                   Currency    98.82     98.80   165.00     70.70
# 1               Stock Market  7674.00   7641.00  7817.00      4.40
# 2            GDP Growth Rate     1.50      2.10    34.90    -28.00
# 3     GDP Annual Growth Rate     2.10      2.70    13.40     -7.40
# 4          Unemployment Rate     4.10      4.20    14.80      2.50
# 5          Non Farm Payrolls   -23.00     20.00  4631.00 -20469.00
# 6             Inflation Rate     3.40      3.50    23.70    -15.80
# 7         Inflation Rate MoM     0.10     -0.40     2.00     -1.80
# 8              Interest Rate     3.75      3.75    20.00      0.25
# 9           Balance of Trade   -73.26    -77.65     1.95   -133.00
# 10           Current Account  -227.00   -221.00     9.96   -438.00
# 11    Current Account to GDP    -3.60     -4.00     0.20     -6.00
# 12    Government Debt to GDP   123.00    122.00   126.00     31.80
# 13         Government Budget    -5.90     -6.30     4.50    -14.50
# 14       Business Confidence    55.60     53.30    77.50     29.40
# 15         Manufacturing PMI    53.20     53.90    63.40     36.10
# 16     Non Manufacturing PMI    54.10     54.00    67.60     37.80
# 17              Services PMI    56.80     54.60    70.40     26.70
# 18       Consumer Confidence    51.00     55.20   111.00     44.80
# 19          Retail Sales MoM    -0.60      0.20    19.30    -14.40
# 20          Building Permits  1443.00   1374.00  2419.00    513.00
# 21        Corporate Tax Rate    21.00     21.00    52.80      1.00
# 22  Personal Income Tax Rate    37.00     37.00    39.60     35.00
#
#         Unnamed: 5 Unnamed: 6
# 0              NaN     Aug/26
# 1           points     Aug/26
# 2          percent     Jun/26
# 3          percent     Jun/26
# 4          percent     Jul/26
# 5         Thousand     Jul/26
# 6          percent     Jul/26
# 7          percent     Jul/26
# 8          percent     Jul/26
# 9      USD Billion     Jun/26
# 10     USD Billion     Mar/26
# 11  percent of GDP     Dec/25
# 12  percent of GDP     Dec/25
# 13  percent of GDP     Dec/25
# 14          points     Jul/26
# 15          points     Aug/26
# 16          points     Jul/26
# 17          points     Aug/26
# 18          points     Aug/26
# 19         percent     Jul/26
# 20        Thousand     Jul/26
# 21         percent     Dec/26
# 22         percent     Dec/26
# /tmp/ipykernel_12852/51921383.py:14: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]  # Assuming there's only one table, otherwise, loop through the list

# %%
df
# Out:
#                   Unnamed: 0     Last  Previous  Highest    Lowest  \
# 0                   Currency    98.82     98.80   165.00     70.70
# 1               Stock Market  7674.00   7641.00  7817.00      4.40
# 2            GDP Growth Rate     1.50      2.10    34.90    -28.00
# 3     GDP Annual Growth Rate     2.10      2.70    13.40     -7.40
# 4          Unemployment Rate     4.10      4.20    14.80      2.50
# 5          Non Farm Payrolls   -23.00     20.00  4631.00 -20469.00
# 6             Inflation Rate     3.40      3.50    23.70    -15.80
# 7         Inflation Rate MoM     0.10     -0.40     2.00     -1.80
# 8              Interest Rate     3.75      3.75    20.00      0.25
# 9           Balance of Trade   -73.26    -77.65     1.95   -133.00
# 10           Current Account  -227.00   -221.00     9.96   -438.00
# 11    Current Account to GDP    -3.60     -4.00     0.20     -6.00
# 12    Government Debt to GDP   123.00    122.00   126.00     31.80
# 13         Government Budget    -5.90     -6.30     4.50    -14.50
# 14       Business Confidence    55.60     53.30    77.50     29.40
# 15         Manufacturing PMI    53.20     53.90    63.40     36.10
# 16     Non Manufacturing PMI    54.10     54.00    67.60     37.80
# 17              Services PMI    56.80     54.60    70.40     26.70
# 18       Consumer Confidence    51.00     55.20   111.00     44.80
# 19          Retail Sales MoM    -0.60      0.20    19.30    -14.40
# 20          Building Permits  1443.00   1374.00  2419.00    513.00
# 21        Corporate Tax Rate    21.00     21.00    52.80      1.00
# 22  Personal Income Tax Rate    37.00     37.00    39.60     35.00
#
#         Unnamed: 5 Unnamed: 6
# 0              NaN     Aug/26
# 1           points     Aug/26
# 2          percent     Jun/26
# 3          percent     Jun/26
# 4          percent     Jul/26
# 5         Thousand     Jul/26
# 6          percent     Jul/26
# 7          percent     Jul/26
# 8          percent     Jul/26
# 9      USD Billion     Jun/26
# 10     USD Billion     Mar/26
# 11  percent of GDP     Dec/25
# 12  percent of GDP     Dec/25
# 13  percent of GDP     Dec/25
# 14          points     Jul/26
# 15          points     Aug/26
# 16          points     Jul/26
# 17          points     Aug/26
# 18          points     Aug/26
# 19         percent     Jul/26
# 20        Thousand     Jul/26
# 21         percent     Dec/26
# 22         percent     Dec/26

# %% [markdown]
# ## 2.5) Financial reporting - EDGAR (in Yahoo)

# %%
# let's check for NVDA
nvda =  yf.Ticker('NVDA')

# %%
# yearly financials for the last 4 years
nvda.financials
# Out:
#                                                       2026-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.511700e-01
# Normalized EBITDA                                   1.445520e+11
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.200670e+11
# Reconciled Depreciation                             2.843000e+09
# Reconciled Cost Of Revenue                          6.247500e+10
# EBITDA                                              1.445520e+11
# EBIT                                                1.417090e+11
# Net Interest Income                                 2.041000e+09
# Interest Expense                                    2.590000e+08
# Interest Income                                     2.300000e+09
# Normalized Income                                   1.200670e+11
# Net Income From Continuing And Discontinued Ope...  1.200670e+11
# Total Expenses                                      8.555100e+10
# Total Operating Income As Reported                  1.303870e+11
# Diluted Average Shares                              2.451400e+10
# Basic Average Shares                                2.435900e+10
# Diluted EPS                                         4.900000e+00
# Basic EPS                                           4.930000e+00
# Diluted NI Availto Com Stockholders                 1.200670e+11
# Net Income Common Stockholders                      1.200670e+11
# Net Income                                          1.200670e+11
# Net Income Including Noncontrolling Interests       1.200670e+11
# Net Income Continuous Operations                    1.200670e+11
# Tax Provision                                       2.138300e+10
# Pretax Income                                       1.414500e+11
# Other Income Expense                                9.022000e+09
# Other Non Operating Income Expenses                 9.022000e+09
# Special Income Charges                                       NaN
# Restructuring And Mergern Acquisition                        NaN
# Net Non Operating Interest Income Expense           2.041000e+09
# Interest Expense Non Operating                      2.590000e+08
# Interest Income Non Operating                       2.300000e+09
# Operating Income                                    1.303870e+11
# Operating Expense                                   2.307600e+10
# Research And Development                            1.849700e+10
# Selling General And Administration                  4.579000e+09
# Gross Profit                                        1.534630e+11
# Cost Of Revenue                                     6.247500e+10
# Total Revenue                                       2.159380e+11
# Operating Revenue                                   2.159380e+11
#
#                                                       2025-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.326490e-01
# Normalized EBITDA                                   8.613700e+10
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  7.288000e+10
# Reconciled Depreciation                             1.864000e+09
# Reconciled Cost Of Revenue                          3.263900e+10
# EBITDA                                              8.613700e+10
# EBIT                                                8.427300e+10
# Net Interest Income                                 1.539000e+09
# Interest Expense                                    2.470000e+08
# Interest Income                                     1.786000e+09
# Normalized Income                                   7.288000e+10
# Net Income From Continuing And Discontinued Ope...  7.288000e+10
# Total Expenses                                      4.904400e+10
# Total Operating Income As Reported                  8.145300e+10
# Diluted Average Shares                              2.480400e+10
# Basic Average Shares                                2.455500e+10
# Diluted EPS                                         2.940000e+00
# Basic EPS                                           2.970000e+00
# Diluted NI Availto Com Stockholders                 7.288000e+10
# Net Income Common Stockholders                      7.288000e+10
# Net Income                                          7.288000e+10
# Net Income Including Noncontrolling Interests       7.288000e+10
# Net Income Continuous Operations                    7.288000e+10
# Tax Provision                                       1.114600e+10
# Pretax Income                                       8.402600e+10
# Other Income Expense                                1.034000e+09
# Other Non Operating Income Expenses                 1.034000e+09
# Special Income Charges                              0.000000e+00
# Restructuring And Mergern Acquisition               0.000000e+00
# Net Non Operating Interest Income Expense           1.539000e+09
# Interest Expense Non Operating                      2.470000e+08
# Interest Income Non Operating                       1.786000e+09
# Operating Income                                    8.145300e+10
# Operating Expense                                   1.640500e+10
# Research And Development                            1.291400e+10
# Selling General And Administration                  3.491000e+09
# Gross Profit                                        9.785800e+10
# Cost Of Revenue                                     3.263900e+10
# Total Revenue                                       1.304970e+11
# Operating Revenue                                   1.304970e+11
#
#                                                       2024-01-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.200000e-01
# Normalized EBITDA                                   3.558300e+10
# Total Unusual Items                                 0.000000e+00
# Total Unusual Items Excluding Goodwill              0.000000e+00
# Net Income From Continuing Operation Net Minori...  2.976000e+10
# Reconciled Depreciation                             1.508000e+09
# Reconciled Cost Of Revenue                          1.662100e+10
# EBITDA                                              3.558300e+10
# EBIT                                                3.407500e+10
# Net Interest Income                                 6.090000e+08
# Interest Expense                                    2.570000e+08
# Interest Income                                     8.660000e+08
# Normalized Income                                   2.976000e+10
# Net Income From Continuing And Discontinued Ope...  2.976000e+10
# Total Expenses                                      2.795000e+10
# Total Operating Income As Reported                  3.297200e+10
# Diluted Average Shares                              2.494000e+10
# Basic Average Shares                                2.469000e+10
# Diluted EPS                                         1.190000e+00
# Basic EPS                                           1.210000e+00
# Diluted NI Availto Com Stockholders                 2.976000e+10
# Net Income Common Stockholders                      2.976000e+10
# Net Income                                          2.976000e+10
# Net Income Including Noncontrolling Interests       2.976000e+10
# Net Income Continuous Operations                    2.976000e+10
# Tax Provision                                       4.058000e+09
# Pretax Income                                       3.381800e+10
# Other Income Expense                                2.370000e+08
# Other Non Operating Income Expenses                 2.370000e+08
# Special Income Charges                              0.000000e+00
# Restructuring And Mergern Acquisition               0.000000e+00
# Net Non Operating Interest Income Expense           6.090000e+08
# Interest Expense Non Operating                      2.570000e+08
# Interest Income Non Operating                       8.660000e+08
# Operating Income                                    3.297200e+10
# Operating Expense                                   1.132900e+10
# Research And Development                            8.675000e+09
# Selling General And Administration                  2.654000e+09
# Gross Profit                                        4.430100e+10
# Cost Of Revenue                                     1.662100e+10
# Total Revenue                                       6.092200e+10
# Operating Revenue                                   6.092200e+10
#
#                                                       2023-01-31  2022-01-31
# Tax Effect Of Unusual Items                        -2.841300e+08         NaN
# Tax Rate For Calcs                                  2.100000e-01         NaN
# Normalized EBITDA                                   7.339000e+09         NaN
# Total Unusual Items                                -1.353000e+09         0.0
# Total Unusual Items Excluding Goodwill             -1.353000e+09         0.0
# Net Income From Continuing Operation Net Minori...  4.368000e+09         NaN
# Reconciled Depreciation                             1.543000e+09         NaN
# Reconciled Cost Of Revenue                          1.161800e+10         NaN
# EBITDA                                              5.986000e+09         NaN
# EBIT                                                4.443000e+09         NaN
# Net Interest Income                                 5.000000e+06         NaN
# Interest Expense                                    2.620000e+08         NaN
# Interest Income                                     2.670000e+08         NaN
# Normalized Income                                   5.436870e+09         NaN
# Net Income From Continuing And Discontinued Ope...  4.368000e+09         NaN
# Total Expenses                                      2.139700e+10         NaN
# Total Operating Income As Reported                  4.224000e+09         NaN
# Diluted Average Shares                              2.507000e+10         NaN
# Basic Average Shares                                2.487000e+10         NaN
# Diluted EPS                                         1.740000e-01         NaN
# Basic EPS                                           1.760000e-01         NaN
# Diluted NI Availto Com Stockholders                 4.368000e+09         NaN
# Net Income Common Stockholders                      4.368000e+09         NaN
# Net Income                                          4.368000e+09         NaN
# Net Income Including Noncontrolling Interests       4.368000e+09         NaN
# Net Income Continuous Operations                    4.368000e+09         NaN
# Tax Provision                                      -1.870000e+08         NaN
# Pretax Income                                       4.181000e+09         NaN
# Other Income Expense                               -1.401000e+09         NaN
# Other Non Operating Income Expenses                -4.800000e+07         NaN
# Special Income Charges                             -1.353000e+09         0.0
# Restructuring And Mergern Acquisition               1.353000e+09         0.0
# Net Non Operating Interest Income Expense           5.000000e+06         NaN
# Interest Expense Non Operating                      2.620000e+08         NaN
# Interest Income Non Operating                       2.670000e+08         NaN
# Operating Income                                    5.577000e+09         NaN
# Operating Expense                                   9.779000e+09         NaN
# Research And Development                            7.339000e+09         NaN
# Selling General And Administration                  2.440000e+09         NaN
# Gross Profit                                        1.535600e+10         NaN
# Cost Of Revenue                                     1.161800e+10         NaN
# Total Revenue                                       2.697400e+10         NaN
# Operating Revenue                                   2.697400e+10         NaN

# %%
# balance sheet
nvda.balance_sheet
# Out:
#                                                     2026-01-31    2025-01-31  \
# Ordinary Shares Number                            2.430400e+10  2.447700e+10
# Share Issued                                      2.430400e+10  2.447700e+10
# Net Debt                                                   NaN           NaN
# Total Debt                                        1.104000e+10  9.982000e+09
# Tangible Book Value                               1.331550e+11  7.333200e+10
# ...                                                        ...           ...
# Receivables                                       3.846600e+10  2.306500e+10
# Accounts Receivable                               3.846600e+10  2.306500e+10
# Cash Cash Equivalents And Short Term Investments  6.255600e+10  4.321000e+10
# Other Short Term Investments                      5.195100e+10  3.462100e+10
# Cash And Cash Equivalents                         1.060500e+10  8.589000e+09
#
#                                                     2024-01-31    2023-01-31  \
# Ordinary Shares Number                            2.464000e+10  2.466137e+10
# Share Issued                                      2.464000e+10  2.466137e+10
# Net Debt                                          2.429000e+09  7.564000e+09
# Total Debt                                        1.105600e+10  1.203100e+10
# Tangible Book Value                               3.743600e+10  1.605300e+10
# ...                                                        ...           ...
# Receivables                                       9.999000e+09  3.827000e+09
# Accounts Receivable                               9.999000e+09  3.827000e+09
# Cash Cash Equivalents And Short Term Investments  2.598400e+10  1.329600e+10
# Other Short Term Investments                      1.870400e+10  9.907000e+09
# Cash And Cash Equivalents                         7.280000e+09  3.389000e+09
#
#                                                     2022-01-31
# Ordinary Shares Number                                     NaN
# Share Issued                                               NaN
# Net Debt                                          8.956000e+09
# Total Debt                                                 NaN
# Tangible Book Value                                        NaN
# ...                                                        ...
# Receivables                                                NaN
# Accounts Receivable                                        NaN
# Cash Cash Equivalents And Short Term Investments           NaN
# Other Short Term Investments                               NaN
# Cash And Cash Equivalents                                  NaN
#
# [80 rows x 5 columns]

# %%
# Basic info:
nvda.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
# marketCap is quite useful, but don't know when it was updated? Daily?
nvda.fast_info['marketCap']/1e9
# Out:
# 5200.73314956665

# %%
# read this article for full info: https://zoo.cs.yale.edu/classes/cs458/lectures/yfinance.html

# %% [markdown]
# ## 2.6 Web Scraping - company info for clustering

# %%
# ask chatGPT: emulate clicking the link and downloading the content
import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://companiesmarketcap.com/"

# Define headers with a user-agent to mimic a web browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# Send a GET request to the URL with headers
response = requests.get(url, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the webpage
    soup = BeautifulSoup(response.content, "html.parser")

    # Find the download link within the webpage
    download_link = soup.find("a", {"rel": "nofollow", "href": "?download=csv"})

    # If the download link is found
    if download_link:
        # Extract the href attribute which contains the actual download link
        download_url = 'https://companiesmarketcap.com/'+download_link["href"]

        # Download the CSV file using the obtained download URL
        download_response = requests.get(download_url, headers=headers)

        # Check if the download request was successful
        if download_response.status_code == 200:
            # Save the content of the response to a local file
            with open("global_stocks.csv", "wb") as f:
                f.write(download_response.content)
            print("CSV file downloaded successfully.")
        else:
            print("Failed to download the CSV file.")
    else:
        print("Download link not found on the webpage.")
else:
    print("Failed to retrieve data from the webpage.")
# Out:
# CSV file downloaded successfully.

# %%
global_stocks = pd.read_csv("/content/global_stocks.csv")

# %%
global_stocks['marketcap_b_usd'] = global_stocks.marketcap/1e9

# %%
global_stocks.head(10)
# Out:
#    Rank               Name   Symbol      marketcap  price (USD)  \
# 0     1             NVIDIA     NVDA  5200733011968    214.72000
# 1     2              Apple     AAPL  4514709504000    309.35000
# 2     3  Alphabet (Google)     GOOG  4179580420096    341.75000
# 3     4          Microsoft     MSFT  3588320657408    483.24000
# 4     5             Amazon     AMZN  2789664358400    258.63000
# 5     6               TSMC      TSM  2172873342976    418.95000
# 6     7             SpaceX     SPCX  1804468355072    136.97000
# 7     8           Broadcom     AVGO  1752930451456    368.45000
# 8     9       Saudi Aramco  2222.SR  1700986928478      7.03156
# 9    10              Tesla     TSLA  1433132728320    362.86000
#
#          country  marketcap_b_usd
# 0  United States      5200.733012
# 1  United States      4514.709504
# 2  United States      4179.580420
# 3  United States      3588.320657
# 4  United States      2789.664358
# 5         Taiwan      2172.873343
# 6  United States      1804.468355
# 7  United States      1752.930451
# 8   Saudi Arabia      1700.986928
# 9  United States      1433.132728

# %%
global_stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11275 entries, 0 to 11274
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             11275 non-null  int64
#  1   Name             11275 non-null  object
#  2   Symbol           11274 non-null  object
#  3   marketcap        11275 non-null  int64
#  4   price (USD)      11275 non-null  float64
#  5   country          11275 non-null  object
#  6   marketcap_b_usd  11275 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 616.7+ KB
